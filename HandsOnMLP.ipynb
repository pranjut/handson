# %%
import tensorflow as tf
import numpy as np
# Out:
# /home/pranjut/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
n_inputs=28*28
n_hidden1=300
n_hidden2=100
n_outputs = 10

# %%
x = tf.placeholder(dtype=tf.float32, shape=(None, n_inputs), name="x")
y = tf.placeholder(dtype=tf.int64, shape=(None), name = "y")

# %%
def neuron_layer(X, n_neurons, name, activation=None):
    with tf.name_scope(name):
        n_inputs = int(X.get_shape()[1])
        stddev = 2 / np.sqrt(n_neurons)
        init = tf.truncated_normal((n_inputs, n_neurons), stddev=stddev)
        W = tf.Variable(init, name="weights")
        b = tf.Variable(tf.zeros(n_neurons), name = "biases")
        z = tf.matmul(X, W) + b
        if activation == "relu":
            return tf.nn.relu(z)
        else:
            return z

# %% [markdown]
# #### Manual way of creating layers

# %%
# with tf.name_scope("dnn"):
#     hidden1 = neuron_layer(x, n_hidden1, "hidden1", activation="relu")
#     hidden2 = neuron_layer(hidden1, n_hidden2, "hidden2",  activation="relu")
#     logits = neuron_layer(hidden2, n_outputs, "outputs")

# %% [markdown]
# #### Tensorflow's default neuron_layers function fully connected layer

# %%
from tensorflow.contrib.layers import fully_connected

with tf.name_scope("dnn_with_fully_connected"):
    hidden1 = fully_connected(x, n_hidden1, scope="hidden1")
    hidden2=fully_connected(hidden1, n_hidden2, scope="hidden2")
    logits = fully_connected(hidden2, n_outputs, scope="outputs", activation_fn=None)

# %%
with tf.name_scope("loss"):
    xentropy = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits)
    loss=tf.reduce_mean(xentropy, name="loss")

# %%
learning_rate = 0.01
with tf.name_scope("train"):
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    training_op = optimizer.minimize(loss)

# %%
with tf.name_scope("eval"):
    correct=tf.nn.in_top_k(logits, y, 1)
    accuracy=tf.reduce_mean(tf.cast(correct, tf.float32))

# %%
init = tf.global_variables_initializer()
saver = tf.train.Saver()

# %%
from tensorflow.examples.tutorials.mnist import input_data

# %%
mnist = input_data.read_data_sets("/tmp/data/")
# Out:
# WARNING:tensorflow:From <ipython-input-12-80aa5e208d67>:1: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /home/pranjut/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /home/pranjut/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
n_epochs=400
batch_size=50

with tf.Session() as sess:
    init.run()
    for epoch in range(n_epochs):
        for iteration in range(mnist.train.num_examples // batch_size):
            x_batch, y_batch = mnist.train.next_batch(batch_size)
            sess.run(training_op, feed_dict={x:x_batch, y:y_batch})
        acc_train=accuracy.eval(feed_dict={x:x_batch, y:y_batch})
        acc_test=accuracy.eval(feed_dict={x:mnist.test.images, y:mnist.test.labels})
        
        print(epoch, "Train Accuracy", acc_train, "Test accuracy", acc_test)
    save_path = saver.save(sess,"./hands_on_mlp.ckpt")
# Out:
# 0 Train Accuracy 0.96 Test accuracy 0.9025
# 1 Train Accuracy 0.9 Test accuracy 0.9231
# 2 Train Accuracy 0.92 Test accuracy 0.9304
# 3 Train Accuracy 0.9 Test accuracy 0.9363
# 4 Train Accuracy 0.94 Test accuracy 0.943
# 5 Train Accuracy 0.94 Test accuracy 0.9477
# 6 Train Accuracy 0.94 Test accuracy 0.951
# 7 Train Accuracy 0.96 Test accuracy 0.9527
# 8 Train Accuracy 0.98 Test accuracy 0.9557
# 9 Train Accuracy 0.96 Test accuracy 0.9576
# 10 Train Accuracy 0.98 Test accuracy 0.9589
# 11 Train Accuracy 0.96 Test accuracy 0.9625
# 12 Train Accuracy 0.98 Test accuracy 0.9639
# 13 Train Accuracy 1.0 Test accuracy 0.9634
# 14 Train Accuracy 1.0 Test accuracy 0.9663
# 15 Train Accuracy 0.98 Test accuracy 0.9682
# 16 Train Accuracy 0.94 Test accuracy 0.9679
# 17 Train Accuracy 0.96 Test accuracy 0.9697
# 18 Train Accuracy 1.0 Test accuracy 0.9705
# 19 Train Accuracy 1.0 Test accuracy 0.9679
# 20 Train Accuracy 1.0 Test accuracy 0.973
# 21 Train Accuracy 1.0 Test accuracy 0.9719
# ...

# %%
with tf.Session() as sess:
    saver.restore(sess,"./hands_on_mlp.ckpt")
    x_batch, y_batch = mnist.train.next_batch(batch_size)
    Z=logits.eval(feed_dict={x:x_batch})
    y_pred=np.argmax(Z, axis=1)
    print(y_pred)
# Out:
# INFO:tensorflow:Restoring parameters from ./hands_on_mlp.ckpt
# [8 0 3 1 4 2 3 0 9 4 1 7 7 8 9 7 7 1 1 6 2 3 9 7 9 9 0 0 0 0 7 5 2 0 0 8 0
#  1 6 1 0 8 9 5 3 4 7 6 5 5]

# %% [markdown]
# #### Q. Why is it generally preferable to use a Logistic Regression classifier rather than a classical Perceptron (i.e., a single layer of linear threshold units trained using the Perceptron training algorithm)? How can you tweak a Perceptron to make it equivalent to a Logistic Regression classifier?

# %% [markdown]
# #### Q. 3. Why was the logistic activation function a key ingredient in training the first MLPs? Name three popular activation functions. Can you draw them?

# %% [markdown]
# Ans: https://medium.com/the-theory-of-everything/understanding-activation-functions-in-neural-networks-9491262884e0
